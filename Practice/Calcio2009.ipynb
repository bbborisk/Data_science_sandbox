# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('season-0910_csv.csv')

# %%
data.head()
data.shape
data.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY',
#        'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'GBH',
#        'GBD', 'GBA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'SBH', 'SBD',
#        'SBA', 'WHH', 'WHD', 'WHA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA',
#        'BSH', 'BSD', 'BSA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD',
#        'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5',
#        'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA',
#        'BbAvAHA'],
#       dtype='object')

# %%
data1 = data[['HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]

# %%
data1
# Out:
#       HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  HST  AST  \
# 0      Bologna  Fiorentina     1     1   D     1     0   H   6  17    4    5
# 1        Siena       Milan     1     2   A     1     1   D  15  13    4    5
# 2      Catania   Sampdoria     1     2   A     1     1   D   8   8    4    4
# 3        Genoa        Roma     3     2   H     0     0   D  14  11    7    6
# 4        Inter        Bari     1     1   D     0     0   D  20  13    3    4
# ..         ...         ...   ...   ...  ..   ...   ...  ..  ..  ..  ...  ...
# 375    Catania       Genoa     1     0   H     0     0   D  22  17    5    4
# 376     Chievo        Roma     0     2   A     0     2   A   9  16    2    6
# 377      Parma     Livorno     4     1   H     1     0   H  25  28   10   12
# 378  Sampdoria      Napoli     1     0   H     0     0   D  15   9    5    5
# 379      Siena       Inter     0     1   A     0     0   D   6  26    2    6
#
#      HF  AF  HC  AC  HY  AY  HR  AR
# ...

# %%
hometeam = data1[['HomeTeam','FTHG','FTR','HTHG','HTR','HS','HST','HF','HC','HY','HR']]

# %%
awayteam = data1[['AwayTeam','FTAG','FTR','HTAG','HTR','AS','AST','AF','AC','AY','AR']]

# %%
season_by_teams = pd.concat(hometeam,awayteam)
# Out:
# /tmp/ipykernel_10418/3198900531.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   season_by_teams = pd.concat(hometeam,awayteam)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10418/3198900531.py in <module>
# ----> 1 season_by_teams = pd.concat(hometeam,awayteam)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# ...
